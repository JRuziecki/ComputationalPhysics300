# %%
import matplotlib.pyplot as plt
import numpy as np
from math import pi

#From Lecture 12

f = lambda x: 1/np.sqrt(x)/(np.exp(x)+1)
w = lambda x: 1/np.sqrt(x)
inv = lambda x: x*x

x = np.linspace(0,1,100)
plt.plot(x, f(x), label='f(x)')
plt.plot(x, w(x), label='w(x)')

plt.legend()
plt.show()
# Out:
# <ipython-input-2-bbb108cd33f4>:7: RuntimeWarning: divide by zero encountered in true_divide
#   f = lambda x: 1/np.sqrt(x)/(np.exp(x)+1)
# <ipython-input-2-bbb108cd33f4>:8: RuntimeWarning: divide by zero encountered in true_divide
#   w = lambda x: 1/np.sqrt(x)
